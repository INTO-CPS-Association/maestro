# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
# define data location
df = read_csv('outputs.csv')
df2 = read_csv('outputs.csv')

df.fillna(0, inplace=True)
df2.fillna(0, inplace=True)

fig, axarr = plt.subplots(2, sharex=True)

#time,{m1}.i1.v1,{m1}.i1.x1,{m2}.i2.fk

#fig = plt.figure()
ax1=axarr[0]
ax1.title.set_text('output1')

ax2 = axarr[1]
ax2.title.set_text('output2')


name='{m1}.i1.v1'
ax1.plot(df['time'], df[name], label=name)
ax2.plot(df2['time'], df2[name], label=name)

name='{m1}.i1.x1'
ax1.plot(df['time'], df[name], label=name)
ax2.plot(df2['time'], df2[name],  label=name)

name='{m2}.i2.fk'
ax1.plot(df['time'], df[name], label=name)
ax2.plot(df2['time'], df2[name],  label=name)


#plt.ylim( (-100, 100) )

plt.legend(bbox_to_anchor=(1, 1),
           bbox_transform=plt.gcf().transFigure)

plt.show()
